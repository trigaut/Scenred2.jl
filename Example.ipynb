# %%
using Scenred2, LightGraphs, TikzGraphs, TikzPictures
# Out:
# WARNING: deprecated syntax "abstract SaveType" at /home/trigaut/.julia/v0.6/TikzPictures/src/TikzPictures.jl:81.
# Use "abstract type SaveType end" instead.

# %%
T = 5
S = 19
R = 2

probas = rand(S)
probas = round.(probas./sum(probas),4)
probas[end] = 1-sum(probas[1:end-1])

scenarios = [Scenred2Scenario(p, round.(rand(T,R),3)) for p in probas ]

fan = Scenred2Fan(T,S,R,scenarios)
# Out:
# Scenred2.Scenred2Fan(5, 19, 2, Scenred2.Scenred2Scenario[Scenred2.Scenred2Scenario(0.0046, [0.679 0.975; 0.071 0.26; … ; 0.324 0.896; 0.349 0.785]), Scenred2.Scenred2Scenario(0.0835, [0.173 0.739; 0.294 0.369; … ; 0.797 0.359; 0.637 0.298]), Scenred2.Scenred2Scenario(0.0337, [0.974 0.386; 0.455 0.777; … ; 0.948 0.807; 0.493 0.877]), Scenred2.Scenred2Scenario(0.0827, [0.014 0.631; 0.401 0.786; … ; 0.148 0.538; 0.472 0.896]), Scenred2.Scenred2Scenario(0.0696, [0.276 0.582; 0.33 0.21; … ; 0.133 0.515; 0.673 0.822]), Scenred2.Scenred2Scenario(0.0378, [0.299 0.282; 0.32 0.759; … ; 0.207 0.887; 0.581 0.204]), Scenred2.Scenred2Scenario(0.0348, [0.218 0.366; 0.993 0.331; … ; 0.971 0.776; 0.064 0.621]), Scenred2.Scenred2Scenario(0.0915, [0.916 0.93; 0.827 0.604; … ; 0.534 0.63; 0.59 0.393]), Scenred2.Scenred2Scenario(0.0838, [0.266 0.301; 0.364 0.46; … ; 0.605 0.244; 0.411 0.819]), Scenred2.Scenred2Scenario(0.0303, [0.962 0.363; 0.782 0.476; … ; 0.052 0.039; 0.343 0.528]), Scenred2.Scenred2Scenario(0.0704, [0.579 0.284; 0.884 0.491; … ; 0.923 0.153; 0.528 0.298]), Scenred2.Scenred2Scenario(0.0973, [0.651 0.893; 0.388 0.976; … ; 0.434 0.666; 0.764 0.841]), Scenred2.Scenred2Scenario(0.0869, [0.668 0.699; 0.49 0.244; … ; 0.035 0.939; 0.995 0.66]), Scenred2.Scenred2Scenario(0.0052, [0.823 0.785; 0.911 0.763; … ; 0.748 0.232; 0.185 0.436]), Scenred2.Scenred2Scenario(0.1009, [0.189 0.358; 0.005 0.77; … ; 0.268 0.766; 0.263 0.482]), Scenred2.Scenred2Scenario(0.022, [0.273 0.972; 0.489 0.274; … ; 0.214 0.287; 0.596 0.812]), Scenred2.Scenred2Scenario(0.0053, [0.943 0.294; 0.095 0.823; … ; 0.655 0.787; 0.619 0.371]), Scenred2.Scenred2Scenario(0.0281, [0.015 0.538; 0.327 0.766; … ; 0.884 0.923; 0.614 0.321]), Scenred2.Scenred2Scenario(0.0316, [0.749 0.699; 0.806 0.203; … ; 0.514 0.321; 0.603 0.89])])

# %%
if S<20
    fdg = DiGraph(fan)
    ft=TikzGraphs.plot(fdg[1], string.(fdg[3]), edge_labels = fdg[2] )
    TikzPictures.save(PDF("fan"), ft)
end

# %%
prms = Scenred2Prms(red_percentage = 0.5)

tree = Scenred2Tree(fan, prms)

gg = Graph(tree)
# Out:
# ***********************************************
# *  SCENARIO TREE CONSTRUCTION / REDUCTION     *
# *                                             *
# *  S C E N R E D - 2                          *
# *                                             *
# *  VERSION: 12/12/2008                        *
# *                                             *
# *  (C) - Humboldt-University Berlin           *
# *        Institute of Mathematics             *
# *        Written by: Holger Heitsch           *
# *                                             *
# ***********************************************
#
# YOU ARE EXECUTING THE COMMAND LINE VERSION
#
# MAIN: READ COMMAND FILE
#     TREE CONSTRUCTION SELECTED
#     READ SCENARIO PARAMETERS
#     OUTPUT OF TREE
# MAIN: READ COMMAND FILE DONE
# MAIN: START TREE CONSTRUCTION
#     DETECT CONSTRUCTION METHOD
#     CONSTRUCTION METHOD BACKWARD
#     READ CONSTRUCTION OPTIONS
#     ASSIGN SCENARIO DISTANCES
#     START BACKWARD TREE CONSTRUCTION
#       REDUCTION METHOD: FORWARD
#     *** SCENARIO TREE CONSTRUCTION SUCCESSFUL
#     CONSTRUCTION SUMMARY
#       CONSTRUCT METHOD: BACKWARD ITERATION
#       REDUCTION METHOD: FORWARD SELECTION
#       METRIC TYPE     : WASSERSTEIN ORDER 1
#       EPSILON GROWTH  : EXPONENTIAL -> SLOPE 0.4045
#       PERCENTAGE (<)  :     0.78
#       TOTAL TIME      :     0.00 (sec)
#         SCENARIO DIST :     0.00 (sec)
#         CONSTRUCT TIME:     0.00 (sec)
#       PROB DISTANCES  : <  77.66 (RELATIVE)
#                         INITIAL       REDUCED
#       SCENARIOS -            19             6
#       NODES     -            77            13
#       STAGES    -             2             4
#     TREE CONSTRUCTION DONE
# MAIN: WRITING TREE
#     TREE DATA FILE </home/trigaut/.julia/v0.6/Scenred2/tmp/scenred2Out.dat>
#
# Any[1 1.0 0.4455 0.5846; 1 1.0 0.401 0.786; 2 0.5445 0.418 0.605; 2 0.4555 0.895 0.326; 3 0.5445 0.148 0.538; 4 0.1967 0.534 0.63; 4 0.2588 0.605 0.244; 5 0.3514 0.472 0.896; 5 0.0869 0.995 0.66; 5 0.1062 0.263 0.482; 6 0.1967 0.59 0.393; 7 0.1168 0.637 0.298; 7 0.142 0.411 0.819]
# ({13, 12} undirected simple Int64 graph, Any[1.0, 0.5445, 0.4555, 0.5445, 0.1967, 0.2588, 0.3514, 0.0869, 0.1062, 0.1967, 0.1168, 0.142], Array{Float64,1}[[0.4455, 0.5846], [0.401, 0.786], [0.418, 0.605], [0.895, 0.326], [0.148, 0.538], [0.534, 0.63], [0.605, 0.244], [0.472, 0.896], [0.995, 0.66], [0.263, 0.482], [0.59, 0.393], [0.637, 0.298], [0.411, 0.819]])

# %%
dg = DiGraph(tree)
# Out:
# ({13, 12} directed simple Int64 graph, Dict{Any,Any}(Pair{Any,Any}((2, 3), 0.5445),Pair{Any,Any}((7, 13), 0.142),Pair{Any,Any}((4, 6), 0.1967),Pair{Any,Any}((4, 7), 0.2588),Pair{Any,Any}((5, 9), 0.0869),Pair{Any,Any}((5, 10), 0.1062),Pair{Any,Any}((5, 8), 0.3514),Pair{Any,Any}((2, 4), 0.4555),Pair{Any,Any}((1, 2), 1.0),Pair{Any,Any}((6, 11), 0.1967)…), Array{Float64,1}[[0.4455, 0.5846], [0.401, 0.786], [0.418, 0.605], [0.895, 0.326], [0.148, 0.538], [0.534, 0.63], [0.605, 0.244], [0.472, 0.896], [0.995, 0.66], [0.263, 0.482], [0.59, 0.393], [0.637, 0.298], [0.411, 0.819]])

# %%
t=TikzGraphs.plot(dg[1], string.(dg[3]), edge_labels = dg[2] )
# Out:
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"[0.4455, 0.5846]\" [],\n2/\"[0.401, 0.786]\" [],\n3/\"[0.418, 0.605]\" [],\n4/\"[0.895, 0.326]\" [],\n5/\"[0.148, 0.538]\" [],\n6/\"[0.534, 0.63]\" [],\n7/\"[0.605, 0.244]\" [],\n8/\"[0.472, 0.896]\" [],\n9/\"[0.995, 0.66]\" [],\n10/\"[0.263, 0.482]\" [],\n11/\"[0.59, 0.393]\" [],\n12/\"[0.637, 0.298]\" [],\n13/\"[0.411, 0.819]\" [],\n;\n1 -> [,edge label={1.0},] 2;\n2 -> [,edge label={0.5445},] 3;\n2 -> [,edge label={0.4555},] 4;\n3 -> [,edge label={0.5445},] 5;\n4 -> [,edge label={0.1967},] 6;\n4 -> [,edge label={0.2588},] 7;\n5 -> [,edge label={0.3514},] 8;\n5 -> [,edge label={0.0869},] 9;\n5 -> [,edge label={0.1062},] 10;\n6 -> [,edge label={0.1967},] 11;\n7 -> [,edge label={0.1168},] 12;\n7 -> [,edge label={0.142},] 13;\n};\n", "", "\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n\\usegdlibrary{layered}", true, true)

# %%
TikzPictures.save(PDF("tree"), t)
